# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
import datetime as dt
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 636

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Lists for holding variables
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Set counter for city number
count = 1

print("Beginning Data Retrieval ")
print("-----------------------------")

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="


# Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        
        print(f"Processing Record {count} | {city}") 
        
        count += 1
   
    except:
        print(f"City not found. Skipping...")
        continue
print("-"*40)
print(f"Data Retrieval Complete")   
print("-"*40)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 | barrow
# Processing Record 2 | vila
# Processing Record 3 | cape town
# Processing Record 4 | katsuura
# Processing Record 5 | jamestown
# Processing Record 6 | nantucket
# City not found. Skipping...
# Processing Record 7 | camargo
# Processing Record 8 | dikson
# Processing Record 9 | jaisalmer
# Processing Record 10 | meulaboh
# Processing Record 11 | husavik
# Processing Record 12 | sangar
# Processing Record 13 | busselton
# Processing Record 14 | caravelas
# Processing Record 15 | bluff
# Processing Record 16 | nome
# Processing Record 17 | ushuaia
# Processing Record 18 | rio grande
# Processing Record 19 | hobart
# Processing Record 20 | rikitea
# Processing Record 21 | mount gambier
# Processing Record 22 | san cristobal
# Processing Record 23 | preston
# Processing Record 24 | mar del plata
# Processing Record 25 | prainha
# Processing Record 26 | boddam
# Processing Record 27 | hilo
# Processing Record 28 | cairns
# Processing Record 29 | grindavik
# City not found. Skipping...
# Processing Record 30 | thompson
# Processing Record 31 | ballyshannon
# Processing Record 32 | port elizabeth
# Processing Record 33 | souillac
# Processing Record 34 | punta arenas
# Processing Record 35 | tuatapere
# Processing Record 36 | salinopolis
# Processing Record 37 | tezu
# Processing Record 38 | atuona
# Processing Record 39 | aklavik
# Processing Record 40 | atasu
# Processing Record 41 | menongue
# Processing Record 42 | saldanha
# Processing Record 43 | anadyr
# Processing Record 44 | sakakah
# Processing Record 45 | albany
# Processing Record 46 | tommot
# Processing Record 47 | santo antonio do ica
# Processing Record 48 | nelson bay
# Processing Record 49 | saskylakh
# Processing Record 50 | hasaki
# Processing Record 51 | mataura
# Processing Record 52 | clyde river
# Processing Record 53 | bima
# Processing Record 54 | las cruces
# Processing Record 55 | san jeronimo
# City not found. Skipping...
# Processing Record 56 | tuktoyaktuk
# Processing Record 57 | pevek
# City not found. Skipping...
# Processing Record 58 | nguru
# Processing Record 59 | hovd
# City not found. Skipping...
# Processing Record 60 | tyup
# Processing Record 61 | vaini
# Processing Record 62 | victoria point
# Processing Record 63 | najran
# Processing Record 64 | lavrentiya
# Processing Record 65 | beloha
# Processing Record 66 | dubbo
# Processing Record 67 | carnarvon
# Processing Record 68 | college
# Processing Record 69 | aras
# Processing Record 70 | saint-philippe
# Processing Record 71 | berdigestyakh
# Processing Record 72 | bumba
# Processing Record 73 | lebu
# Processing Record 74 | beidao
# City not found. Skipping...
# Processing Record 75 | pimentel
# Processing Record 76 | cockburn town
# Processing Record 77 | mamallapuram
# Processing Record 78 | castro
# Processing Record 79 | tromso
# Processing Record 80 | kabare
# Processing Record 81 | ribeira grande
# Processing Record 82 | ozernovskiy
# Processing Record 83 | ponta do sol
# Processing Record 84 | kindu
# City not found. Skipping...
# Processing Record 85 | yellowknife
# Processing Record 86 | hithadhoo
# Processing Record 87 | nikolskoye
# Processing Record 88 | zharkovskiy
# Processing Record 89 | olafsvik
# Processing Record 90 | cidreira
# Processing Record 91 | hermanus
# Processing Record 92 | namatanai
# Processing Record 93 | leningradskiy
# Processing Record 94 | mahibadhoo
# Processing Record 95 | saint george
# Processing Record 96 | praia da vitoria
# Processing Record 97 | port alfred
# Processing Record 98 | new norfolk
# Processing Record 99 | krabi
# Processing Record 100 | wladyslawowo
# Processing Record 101 | kapaa
# Processing Record 102 | hami
# Processing Record 103 | comodoro rivadavia
# Processing Record 104 | bengkulu
# Processing Record 105 | acapulco
# Processing Record 106 | shingu
# Processing Record 107 | chokurdakh
# Processing Record 108 | scarborough
# Processing Record 109 | qaanaaq
# Processing Record 110 | rio gallegos
# Processing Record 111 | maningrida
# City not found. Skipping...
# Processing Record 112 | kaitangata
# Processing Record 113 | port lincoln
# Processing Record 114 | upernavik
# Processing Record 115 | abu samrah
# Processing Record 116 | birjand
# Processing Record 117 | san patricio
# Processing Record 118 | cravo norte
# Processing Record 119 | pemangkat
# Processing Record 120 | singaraja
# Processing Record 121 | kosa
# Processing Record 122 | camacha
# Processing Record 123 | makakilo city
# Processing Record 124 | victoria
# Processing Record 125 | kiruna
# Processing Record 126 | urucara
# Processing Record 127 | pucara
# Processing Record 128 | turinsk
# Processing Record 129 | vestmanna
# City not found. Skipping...
# Processing Record 130 | skibbereen
# Processing Record 131 | tura
# Processing Record 132 | bonavista
# Processing Record 133 | puerto ayora
# Processing Record 134 | havre
# Processing Record 135 | pemba
# Processing Record 136 | sitka
# Processing Record 137 | wuzhou
# Processing Record 138 | marsh harbour
# Processing Record 139 | chuy
# Processing Record 140 | yulara
# Processing Record 141 | sangmelima
# Processing Record 142 | camajuani
# Processing Record 143 | calama
# Processing Record 144 | mumbwa
# Processing Record 145 | port moresby
# Processing Record 146 | arlit
# City not found. Skipping...
# Processing Record 147 | esperance
# Processing Record 148 | cabo san lucas
# Processing Record 149 | bathsheba
# Processing Record 150 | narsaq
# Processing Record 151 | bredasdorp
# Processing Record 152 | dalvik
# Processing Record 153 | daloa
# Processing Record 154 | nanortalik
# Processing Record 155 | latung
# Processing Record 156 | rawson
# Processing Record 157 | sao gabriel da cachoeira
# City not found. Skipping...
# Processing Record 158 | surt
# Processing Record 159 | sosnovo-ozerskoye
# Processing Record 160 | bernissart
# Processing Record 161 | darhan
# Processing Record 162 | arraial do cabo
# Processing Record 163 | constitucion
# Processing Record 164 | east london
# Processing Record 165 | srednekolymsk
# Processing Record 166 | taunggyi
# Processing Record 167 | moron
# Processing Record 168 | kruisfontein
# Processing Record 169 | bendigo
# Processing Record 170 | palmer
# Processing Record 171 | kumano
# Processing Record 172 | muros
# City not found. Skipping...
# Processing Record 173 | berlevag
# City not found. Skipping...
# Processing Record 174 | kinsale
# City not found. Skipping...
# Processing Record 175 | ginir
# Processing Record 176 | gat
# Processing Record 177 | butaritari
# Processing Record 178 | la rioja
# Processing Record 179 | kavaratti
# Processing Record 180 | verkhoyansk
# Processing Record 181 | yeniseysk
# Processing Record 182 | portland
# Processing Record 183 | longyearbyen
# Processing Record 184 | cortez
# Processing Record 185 | baykit
# Processing Record 186 | ladario
# Processing Record 187 | the valley
# Processing Record 188 | meadow lake
# Processing Record 189 | isangel
# City not found. Skipping...
# Processing Record 190 | bowen
# Processing Record 191 | lompoc
# Processing Record 192 | pahrump
# Processing Record 193 | talakan
# Processing Record 194 | concepcion del oro
# Processing Record 195 | vangaindrano
# Processing Record 196 | pacific grove
# Processing Record 197 | xinxiang
# Processing Record 198 | murgab
# Processing Record 199 | pampierstad
# Processing Record 200 | petropavl
# Processing Record 201 | praia
# City not found. Skipping...
# Processing Record 202 | suntar
# Processing Record 203 | jatiroto
# Processing Record 204 | namibe
# Processing Record 205 | soyo
# Processing Record 206 | vitim
# Processing Record 207 | esna
# Processing Record 208 | yichang
# Processing Record 209 | south lake tahoe
# City not found. Skipping...
# Processing Record 210 | graaff-reinet
# Processing Record 211 | port-gentil
# Processing Record 212 | changping
# Processing Record 213 | illapel
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 214 | kodiak
# Processing Record 215 | san carlos de bariloche
# City not found. Skipping...
# Processing Record 216 | hof
# Processing Record 217 | kloulklubed
# Processing Record 218 | kuching
# Processing Record 219 | acajutla
# Processing Record 220 | mindelo
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 221 | horta
# Processing Record 222 | rundu
# Processing Record 223 | san jose
# Processing Record 224 | noumea
# Processing Record 225 | balaoang
# Processing Record 226 | guilin
# Processing Record 227 | ancud
# Processing Record 228 | montero
# Processing Record 229 | aksarka
# City not found. Skipping...
# Processing Record 230 | tasiilaq
# Processing Record 231 | ahipara
# Processing Record 232 | buraydah
# Processing Record 233 | altay
# Processing Record 234 | hofn
# Processing Record 235 | sao joao da barra
# Processing Record 236 | zhigansk
# Processing Record 237 | port blair
# City not found. Skipping...
# Processing Record 238 | bambous virieux
# City not found. Skipping...
# Processing Record 239 | medina
# Processing Record 240 | pangnirtung
# Processing Record 241 | bhadrachalam
# Processing Record 242 | saint-francois
# Processing Record 243 | buala
# Processing Record 244 | coquimbo
# Processing Record 245 | ambulu
# Processing Record 246 | kungurtug
# Processing Record 247 | beringovskiy
# Processing Record 248 | druzhba
# Processing Record 249 | broken hill
# City not found. Skipping...
# Processing Record 250 | rey bouba
# Processing Record 251 | avarua
# Processing Record 252 | lac du bonnet
# City not found. Skipping...
# Processing Record 253 | kaeo
# Processing Record 254 | ambilobe
# Processing Record 255 | klaksvik
# Processing Record 256 | lamar
# Processing Record 257 | senanga
# Processing Record 258 | severo-kurilsk
# Processing Record 259 | silao
# Processing Record 260 | karpogory
# Processing Record 261 | high level
# Processing Record 262 | bitung
# Processing Record 263 | chengde
# Processing Record 264 | hay river
# Processing Record 265 | sistranda
# Processing Record 266 | cayenne
# Processing Record 267 | alushta
# Processing Record 268 | leh
# Processing Record 269 | lyubech
# Processing Record 270 | zhezkazgan
# Processing Record 271 | busko-zdroj
# Processing Record 272 | bethel
# Processing Record 273 | tanggu
# Processing Record 274 | la paz
# Processing Record 275 | quesnel
# Processing Record 276 | vardo
# Processing Record 277 | przeworsk
# Processing Record 278 | kuito
# Processing Record 279 | sao filipe
# Processing Record 280 | vanimo
# Processing Record 281 | ulagan
# City not found. Skipping...
# Processing Record 282 | ewa beach
# Processing Record 283 | atar
# Processing Record 284 | salina cruz
# City not found. Skipping...
# Processing Record 285 | khatanga
# Processing Record 286 | codrington
# Processing Record 287 | yuancheng
# Processing Record 288 | norman wells
# Processing Record 289 | tres arroyos
# Processing Record 290 | sao paulo de olivenca
# Processing Record 291 | bardiyah
# Processing Record 292 | billings
# Processing Record 293 | iqaluit
# Processing Record 294 | zaysan
# Processing Record 295 | sabang
# Processing Record 296 | san lawrenz
# Processing Record 297 | biak
# Processing Record 298 | kahului
# Processing Record 299 | pacifica
# Processing Record 300 | kenai
# Processing Record 301 | tiarei
# Processing Record 302 | varginha
# Processing Record 303 | jining
# Processing Record 304 | pumiao
# Processing Record 305 | labuhan
# Processing Record 306 | margate
# Processing Record 307 | henties bay
# Processing Record 308 | jurm
# Processing Record 309 | ilulissat
# Processing Record 310 | sawakin
# Processing Record 311 | uray
# City not found. Skipping...
# Processing Record 312 | petropavlovsk-kamchatskiy
# Processing Record 313 | georgetown
# Processing Record 314 | tevriz
# Processing Record 315 | nadym
# Processing Record 316 | cherskiy
# Processing Record 317 | dwarka
# Processing Record 318 | hirara
# Processing Record 319 | tepusteca
# Processing Record 320 | mikuni
# Processing Record 321 | gorgan
# Processing Record 322 | mahebourg
# Processing Record 323 | davydivka
# Processing Record 324 | la libertad
# Processing Record 325 | jos
# City not found. Skipping...
# Processing Record 326 | trindade
# Processing Record 327 | sinnamary
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 328 | redlands
# Processing Record 329 | alyangula
# City not found. Skipping...
# Processing Record 330 | bontang
# Processing Record 331 | brae
# Processing Record 332 | domoni
# Processing Record 333 | aykhal
# Processing Record 334 | tangzhai
# Processing Record 335 | tenenkou
# Processing Record 336 | hamilton
# Processing Record 337 | naron
# Processing Record 338 | quatre cocos
# Processing Record 339 | lagoa
# Processing Record 340 | haines junction
# City not found. Skipping...
# Processing Record 341 | aitape
# Processing Record 342 | licata
# Processing Record 343 | mkuranga
# Processing Record 344 | luderitz
# Processing Record 345 | touros
# Processing Record 346 | channel-port aux basques
# Processing Record 347 | northam
# Processing Record 348 | along
# Processing Record 349 | dhidhdhoo
# Processing Record 350 | ponta delgada
# City not found. Skipping...
# Processing Record 351 | santa rosalia
# Processing Record 352 | mulege
# Processing Record 353 | ottumwa
# Processing Record 354 | trairi
# Processing Record 355 | mimongo
# Processing Record 356 | pekan
# Processing Record 357 | derazhnya
# Processing Record 358 | edd
# Processing Record 359 | shimoda
# Processing Record 360 | nouakchott
# Processing Record 361 | diamantino
# Processing Record 362 | traiguen
# Processing Record 363 | bafra
# Processing Record 364 | pochutla
# Processing Record 365 | timizart
# Processing Record 366 | bilibino
# Processing Record 367 | ostersund
# Processing Record 368 | kavieng
# Processing Record 369 | faanui
# Processing Record 370 | oranjestad
# Processing Record 371 | krasnoarmeysk
# Processing Record 372 | vestmannaeyjar
# Processing Record 373 | airai
# Processing Record 374 | namtsy
# Processing Record 375 | neuquen
# Processing Record 376 | kutum
# Processing Record 377 | dali
# Processing Record 378 | jalu
# Processing Record 379 | avera
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 380 | bemidji
# Processing Record 381 | provideniya
# Processing Record 382 | dingle
# Processing Record 383 | rocha
# Processing Record 384 | xingyi
# Processing Record 385 | oriximina
# Processing Record 386 | hambantota
# Processing Record 387 | kedrovyy
# Processing Record 388 | khandyga
# Processing Record 389 | khandagayty
# Processing Record 390 | vila franca do campo
# Processing Record 391 | giyon
# Processing Record 392 | kampene
# Processing Record 393 | shchelkun
# Processing Record 394 | gawler
# Processing Record 395 | amahai
# Processing Record 396 | ubinskoye
# Processing Record 397 | banda aceh
# Processing Record 398 | saint anthony
# Processing Record 399 | te anau
# City not found. Skipping...
# Processing Record 400 | nioro
# Processing Record 401 | marzuq
# Processing Record 402 | terrace
# City not found. Skipping...
# Processing Record 403 | mehamn
# Processing Record 404 | darab
# Processing Record 405 | mgandu
# Processing Record 406 | el angel
# Processing Record 407 | north bend
# Processing Record 408 | sorkjosen
# City not found. Skipping...
# Processing Record 409 | faya
# Processing Record 410 | niono
# Processing Record 411 | rognan
# Processing Record 412 | adrar
# Processing Record 413 | teguise
# Processing Record 414 | alofi
# Processing Record 415 | vostok
# Processing Record 416 | coihaique
# Processing Record 417 | berberati
# Processing Record 418 | palana
# Processing Record 419 | padang
# Processing Record 420 | gazanjyk
# Processing Record 421 | bagotville
# Processing Record 422 | kobryn
# Processing Record 423 | ornskoldsvik
# Processing Record 424 | inndyr
# Processing Record 425 | pointe michel
# Processing Record 426 | cleveland
# Processing Record 427 | oussouye
# Processing Record 428 | tual
# Processing Record 429 | fortuna
# Processing Record 430 | madang
# Processing Record 431 | kulu
# Processing Record 432 | los llanos de aridane
# Processing Record 433 | anamur
# Processing Record 434 | luwuk
# Processing Record 435 | kishi
# Processing Record 436 | teshie
# Processing Record 437 | korla
# City not found. Skipping...
# Processing Record 438 | komsomolskiy
# Processing Record 439 | rockport
# Processing Record 440 | maridi
# Processing Record 441 | reconquista
# Processing Record 442 | damascus
# City not found. Skipping...
# Processing Record 443 | sernovodsk
# Processing Record 444 | santa cruz cabralia
# Processing Record 445 | torbay
# Processing Record 446 | areosa
# Processing Record 447 | celestun
# Processing Record 448 | madarounfa
# Processing Record 449 | honningsvag
# Processing Record 450 | salalah
# City not found. Skipping...
# Processing Record 451 | samarai
# Processing Record 452 | algiers
# Processing Record 453 | maiduguri
# Processing Record 454 | port hardy
# Processing Record 455 | hanzhong
# Processing Record 456 | fort nelson
# Processing Record 457 | san luis
# Processing Record 458 | lokoja
# Processing Record 459 | sri aman
# Processing Record 460 | saint-augustin
# Processing Record 461 | hit
# Processing Record 462 | olinda
# Processing Record 463 | half moon bay
# Processing Record 464 | mariental
# Processing Record 465 | bandarbeyla
# Processing Record 466 | ouro preto
# Processing Record 467 | kholm
# City not found. Skipping...
# Processing Record 468 | glendive
# Processing Record 469 | pathein
# Processing Record 470 | tilichiki
# Processing Record 471 | waipawa
# Processing Record 472 | manokwari
# Processing Record 473 | shenjiamen
# Processing Record 474 | kuala terengganu
# Processing Record 475 | huntington
# Processing Record 476 | lukovetskiy
# Processing Record 477 | cabudare
# Processing Record 478 | karratha
# Processing Record 479 | geraldton
# Processing Record 480 | lasa
# City not found. Skipping...
# Processing Record 481 | udachnyy
# Processing Record 482 | owando
# Processing Record 483 | zirandaro
# Processing Record 484 | moranbah
# Processing Record 485 | nuuk
# Processing Record 486 | simao
# Processing Record 487 | havoysund
# Processing Record 488 | rudnogorsk
# Processing Record 489 | glenwood springs
# Processing Record 490 | ust-kuyga
# Processing Record 491 | puerto quijarro
# City not found. Skipping...
# Processing Record 492 | egvekinot
# Processing Record 493 | sur
# Processing Record 494 | port macquarie
# Processing Record 495 | tallahassee
# Processing Record 496 | miraflores
# Processing Record 497 | barra do garcas
# Processing Record 498 | novikovo
# Processing Record 499 | midland
# Processing Record 500 | araouane
# Processing Record 501 | yumen
# Processing Record 502 | wyndham
# City not found. Skipping...
# Processing Record 503 | qazvin
# Processing Record 504 | christchurch
# Processing Record 505 | lasem
# Processing Record 506 | san quintin
# Processing Record 507 | vicuna
# Processing Record 508 | fairbanks
# Processing Record 509 | pisco
# Processing Record 510 | lere
# Processing Record 511 | daitari
# Processing Record 512 | yining
# Processing Record 513 | komsomolets
# Processing Record 514 | moroto
# Processing Record 515 | boueni
# Processing Record 516 | tecoanapa
# Processing Record 517 | liwale
# Processing Record 518 | dicabisagan
# Processing Record 519 | vila velha
# Processing Record 520 | polignano a mare
# Processing Record 521 | ayan
# Processing Record 522 | bjornevatn
# Processing Record 523 | noyabrsk
# Processing Record 524 | houston
# Processing Record 525 | velsk
# Processing Record 526 | santa isabel do rio negro
# Processing Record 527 | jamui
# Processing Record 528 | ust-ishim
# Processing Record 529 | kenora
# Processing Record 530 | umm lajj
# Processing Record 531 | clayton
# Processing Record 532 | at-bashi
# Processing Record 533 | bela
# Processing Record 534 | guerrero negro
# Processing Record 535 | chor
# Processing Record 536 | san-pedro
# Processing Record 537 | sungaipenuh
# Processing Record 538 | krasnoselkup
# Processing Record 539 | boditi
# Processing Record 540 | chara
# City not found. Skipping...
# Processing Record 541 | pedernales
# Processing Record 542 | tiksi
# Processing Record 543 | boyolangu
# City not found. Skipping...
# Processing Record 544 | puerto narino
# Processing Record 545 | chernushka
# Processing Record 546 | ibra
# Processing Record 547 | ekhabi
# Processing Record 548 | champaign
# Processing Record 549 | bundaberg
# Processing Record 550 | roald
# Processing Record 551 | batasan
# Processing Record 552 | emerald
# Processing Record 553 | derzhavinsk
# Processing Record 554 | grand-lahou
# Processing Record 555 | richards bay
# Processing Record 556 | orichi
# Processing Record 557 | takoradi
# Processing Record 558 | itoman
# Processing Record 559 | kearney
# Processing Record 560 | idah
# Processing Record 561 | flinders
# Processing Record 562 | puerto madero
# City not found. Skipping...
# Processing Record 563 | scituate
# Processing Record 564 | deputatskiy
# Processing Record 565 | tessalit
# Processing Record 566 | lakatoro
# Processing Record 567 | hammerfest
# Processing Record 568 | flin flon
# Processing Record 569 | mikumi
# Processing Record 570 | vao
# Processing Record 571 | kulhudhuffushi
# Processing Record 572 | isla mujeres
# Processing Record 573 | mizdah
# Processing Record 574 | sokoto
# Processing Record 575 | kurilsk
# Processing Record 576 | znamenskoye
# Processing Record 577 | kalemie
# Processing Record 578 | diego de almagro
# Processing Record 579 | umm kaddadah
# Processing Record 580 | batagay-alyta
# Processing Record 581 | elko
# Processing Record 582 | erdemli
# Processing Record 583 | independencia
# Processing Record 584 | atikokan
# ----------------------------------------
# Data Retrieval Complete
# ----------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a data frame from cities, lat, and temp
weather_dict = {
    "City": city_name,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
}

city_data = pd.DataFrame(weather_dict)

# Save data frame to CSV
city_data.to_csv("cities.csv")

city_data.head()
# Out:
#         City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Barrow  71.29 -156.79     24.80        92          75        6.93
# 1       Vila  42.03   -8.16     55.00        94         100        3.96
# 2  Cape Town -33.93   18.42     60.01        67           0       13.87
# 3   Katsuura  35.13  140.30     60.80        77          20       13.87
# 4  Jamestown  42.10  -79.24     50.00       100          90        6.93
#
#   Country        Date
# 0      US  10/20/2020
# 1      PT  10/20/2020
# 2      ZA  10/20/2020
# 3      JP  10/20/2020
# 4      US  10/20/2020

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  584.000000  584.000000  584.000000  584.000000  584.000000  584.000000
# mean    20.968510   18.667894   61.128579   69.856164   52.356164    7.846798
# std     33.147375   90.167824   21.423010   23.363190   37.925265    5.449539
# min    -54.800000 -179.170000    7.830000    1.000000    0.000000    0.200000
# 25%     -3.777500  -59.807500   45.600000   57.750000   15.000000    3.500000
# 50%     24.860000   22.880000   64.805000   76.000000   58.500000    6.870000
# 75%     49.640000   97.867500   78.090000   88.000000   90.000000   10.667500
# max     78.220000  179.320000  102.650000  100.000000  100.000000   30.650000
#
#                Date
# count  5.840000e+02
# mean   1.603218e+09
# std    7.061347e+01
# min    1.603218e+09
# 25%    1.603218e+09
# 50%    1.603219e+09
# 75%    1.603219e+09
# max    1.603219e+09

# %%
#  Get the indices of cities that have humidity over 100%.
print(city_data.loc[city_data.Humidity >100].index)
print(city_data["Humidity"].max())

# Output shows not cities with humidity over 100.
# Out:
# Int64Index([], dtype='int64')
# 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".


#N/A
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Set today's date for chart title
date = dt.date.today().strftime("%m/%d/%Y")

# Create Latitude vs. Temperature scatter plot
plt.scatter(city_data["Lat"], city_data["Max Temp"], marker="o",s = 20, alpha = .75, edgecolors = "black")
plt.title(f"City Latitude vs. Max Temperature {date}")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#Save graph
plt.savefig("City Latitude vs Max Temperature.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Set today's date for chart title
date = dt.date.today().strftime("%m/%d/%Y")

# Create Latitude vs. Humidity scatter plot
plt.scatter(city_data["Lat"], city_data["Humidity"], marker="o",s = 20, alpha = .75, edgecolors = "black")
plt.title(f"City Latitude vs. Humidity {date}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

#Save graph
plt.savefig("City Latitude vs Humidity.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Set today's date for chart title
date = dt.date.today().strftime("%m/%d/%Y")

# Create Latitude vs. Cloudiness scatter plot
plt.scatter(city_data["Lat"], city_data["Cloudiness"], marker="o",s = 20, alpha = .75, edgecolors = "black")
plt.title(f"City Latitude vs. Cloudiness {date}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

#Save graph
plt.savefig("City Latitude vs Cloudiness.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Set today's date for chart title
date = dt.date.today().strftime("%m/%d/%Y")

# Create Latitude vs. Wind Speed scatter plot
plt.scatter(city_data["Lat"], city_data["Wind Speed"], marker="o",s = 20, alpha = .75, edgecolors = "black")
plt.title(f"City Latitude vs. Wind Speed {date}")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

#Save graph
plt.savefig("City Latitude vs Wind Speed.png")

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = city_data.loc[city_data["Lat"] >= 0]
southern_df = city_data.loc[city_data["Lat"] < 0]

# Define function for creating linear regression and scatter plot
def linear_regression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    print(f"The r-value is: {rvalue}")
    return line_eq

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call function to create linear regression
equation = linear_regression(northern_df["Lat"], northern_df["Max Temp"])

# Formatting/Cleanup
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.annotate(equation,(5,20), fontsize = 15, color = "red")

# Save the figure
plt.savefig("Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-value is: -0.8759787288143054

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
